# %% [markdown]
# # Retinopathy grading on Kaggle
#
# Enable a free GPU, attach the `diabetic-retinopathy-224x224-2019-data` dataset, and clone this repository. The notebook calls the repository scripts so local and Kaggle training use the same implementation.

# %%
# !pip install -q -r requirements-dev.txt
# !pip install -q -e .

# %%
DATASET_ROOT = "/kaggle/input/diabetic-retinopathy-224x224-2019-data"
# !python scripts/prepare_data.py --dataset-root "$DATASET_ROOT"
# !python scripts/train_model.py --dataset-root "$DATASET_ROOT"
